# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import tabula

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### Bus Ridership and Stop Usage Data
#
# sources:
# - https://data.wprdc.org/dataset/prt-transit-stop-usage
# - https://data.wprdc.org/dataset/prt-monthly-average-ridership-by-route

# %%
ridership_df = pd.read_csv("Data/avg_ridership.csv")
ridership_df.head()
# Out:
#    _id route ridership_route_code    route_full_name current_garage mode  \
# 0    1     1                  001  1 - FREEPORT ROAD           Ross  Bus
# 1    2     4                  004      4 - TROY HILL           Ross  Bus
# 2    3     6                  006    6 - SPRING HILL           Ross  Bus
# 3    4     8                  008    8 - PERRYSVILLE           Ross  Bus
# 4    5    11                  011      11 - FINEVIEW           Ross  Bus
#
#   month_start  year_month day_type  avg_riders  day_count
# 0  2017-01-01      201701     SAT.      969.50          4
# 1  2017-01-01      201701     SAT.      218.25          4
# 2  2017-01-01      201701     SAT.      495.50          4
# 3  2017-01-01      201701     SAT.     1480.00          4
# 4  2017-01-01      201701     SAT.      208.00          4

# %%
stopuse_df = pd.read_csv("Data/wprdc_stop_data.csv")
stopuse_df.head()
# Out:
#    clever_id stop_id            stop_name direction routes_ser  latitude  \
# 0       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 1       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 2       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 3       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 4       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
#
#    longitude mode     shelter stop_type  datekey   time_period route_name  \
# 0     -79.76  Bus  No Shelter  Bus Stop   201909  Pre-pandemic         69
# 1     -79.76  Bus  No Shelter  Bus Stop   201909  Pre-pandemic         69
# 2     -79.76  Bus  No Shelter  Bus Stop   201909  Pre-pandemic         69
# 3     -79.76  Bus  No Shelter  Bus Stop   201909  Pre-pandemic        P69
# 4     -79.76  Bus  No Shelter  Bus Stop   202001  Pre-pandemic         69
#
#   serviceday  total_ons  total_offs  days   avg_ons  avg_offs
# 0        Sat       12.0         0.0     4  3.000000      0.00
# 1        Sun       14.0         0.0     6  2.333333      0.00
# 2    Weekday       64.0         1.0    20  3.200000      0.05
# 3    Weekday       39.0         0.0    20  1.950000      0.00
# 4        Sat       11.0         0.0     4  2.750000      0.00

# %% [markdown]
# ### Weather Data

# %%
## Monthly average temperatures in Pittsburgh, PA
temp_url = "https://www.weather.gov/media/pbz/records/histemp.pdf"
temp_df = tabula.read_pdf(temp_url, pages = 'all')[2]

# %%
cols = ['Year', 'January', 'February', 'March', 
        'April', 'May', 'June', 'July', 'August', 
        'September', 'October', 'November', 'December', 'Annual']
temp_df.columns = cols

# %%
temps_2024 = [2024, 33.0, 39.5, 46.6, 56.9, 66.5, 72.8, 76.5, 73.8, 69.4, 57.0, 47.6, 36.6, 56.4]
temps_2025 = [2025, 24.1, 31.7, 47.4] + [np.nan for i in range(len(cols)-3)]

temps_2024_df = dict(zip(cols, temps_2024))
temps_2024_df = pd.DataFrame(temps_2024_df, index = [1])

temps_2025_df = dict(zip(cols, temps_2025))
temps_2025_df = pd.DataFrame(temps_2025_df, index = [1])

# %%
temp_df = pd.concat([temp_df, temps_2024_df, temps_2025_df])
temp_df.reset_index(drop = True, inplace = True)
temp_df.head()
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1975     32.6      32.1   36.3   44.3  63.0  57.8  72.8    73.0       58.8
# 1  1976     23.5      37.2   45.2   50.6  55.6  68.4  67.4    65.3       59.9
# 2  1977     11.4      26.9   43.7   50.8  63.0  63.8  71.8    68.1       64.7
# 3  1978     22.6      20.9   36.9   51.0  60.2  69.4  73.0    71.4       66.2
# 4  1979     21.4      18.0   43.1   49.7  59.1  67.7  70.3    69.6       63.4
#
#    October  November  December  Annual
# 0     53.3      46.3      32.9    51.1
# 1     45.9      33.1      23.9    48.0
# 2     50.5      45.6      31.1    49.3
# 3     49.1      43.0      32.7    49.7
# 4     50.9      44.7      34.6    49.4

# %%
temp_df = temp_df.melt(id_vars = ['Year'], 
                       var_name = 'Month', 
                       value_name = 'avg_temp')
temp_df.head()
# Out:
#    Year    Month  avg_temp
# 0  1975  January      32.6
# 1  1976  January      23.5
# 2  1977  January      11.4
# 3  1978  January      22.6
# 4  1979  January      21.4

# %%
temp_df = temp_df[temp_df['Month'] != 'Annual'].copy()
temp_df = temp_df[temp_df['Year'] != '30 yr'].copy()

d = dict((v,k) for k,v in zip(range(1, 13), temp_df.Month.unique()))
temp_df['month_index'] = temp_df['Month'].map(d)
temp_df['year_month'] = temp_df['Year'].astype(str) + temp_df['month_index'].astype(str).str.zfill(2)

temp_df
# Out:
#      Year     Month  avg_temp  month_index year_month
# 0    1975   January      32.6            1     197501
# 1    1976   January      23.5            1     197601
# 2    1977   January      11.4            1     197701
# 3    1978   January      22.6            1     197801
# 4    1979   January      21.4            1     197901
# ..    ...       ...       ...          ...        ...
# 607  2021  December      40.9           12     202112
# 608  2022  December      33.0           12     202212
# 609  2023  December      42.7           12     202312
# 610  2024  December      36.6           12     202412
# 611  2025  December       NaN           12     202512
#
# [612 rows x 5 columns]

# %%
## Monthly total precipitation (inches) in Pittsburgh, PA
precip_url = "https://www.weather.gov/media/pbz/records/hisprec.pdf"
precip_df = tabula.read_pdf(precip_url, pages = 'all')[2]

# %%
precip_df.columns = ['Year', 'January', 'February', 'March', 
                     'April', 'May', 'June', 'July', 'August', 
                     'September', 'October', 'November', 'December', 'Annual']
precip_df.head()
# Out:
#    Year  January  February  March  April   May  June  July  August  September  \
# 0  1964     2.55      1.73   4.96   7.61  1.77  3.84  4.48    1.79       0.74
# 1  1965     3.84      2.98   3.16   1.79  1.21  2.31  1.82    3.26       4.07
# 2  1966     4.52      3.23   1.88   3.73  2.76  1.72  2.70    5.13       1.92
# 3  1967     1.06      2.54   6.10   4.41  5.21  0.90  4.54    2.67       1.61
# 4  1968     2.83      0.79   4.53   2.33  6.36  2.38  2.36    3.97       3.08
#
#    October  November  December  Annual
# 0     1.42      2.74      4.26   37.89
# 1     2.82      2.35      0.63   30.24
# 2     1.38      3.39      1.70   34.06
# 3     2.05      3.07      2.22   36.38
# 4     2.13      2.07      3.24   36.07

# %%
precip_df = precip_df.melt(id_vars = ['Year'], 
                           var_name = 'Month', 
                           value_name = 'total_precip')
precip_df.head()
# Out:
#    Year    Month  total_precip
# 0  1964  January          2.55
# 1  1965  January          3.84
# 2  1966  January          4.52
# 3  1967  January          1.06
# 4  1968  January          2.83

# %%
precip_df = precip_df[precip_df['Month'] != 'Annual'].copy()
precip_df = precip_df[precip_df['Year'] != '30 yr'].copy()

d = dict((v,k) for k,v in zip(range(1, 13), precip_df.Month.unique()))
precip_df['month_index'] = precip_df['Month'].map(d)
precip_df['year_month'] = precip_df['Year'].astype(str) + precip_df['month_index'].astype(str).str.zfill(2)

precip_df
# Out:
#      Year     Month  total_precip  month_index year_month
# 0    1964   January          2.55            1     196401
# 1    1965   January          3.84            1     196501
# 2    1966   January          4.52            1     196601
# 3    1967   January          1.06            1     196701
# 4    1968   January          2.83            1     196801
# ..    ...       ...           ...          ...        ...
# 750  2021  December          3.45           12     202112
# 751  2022  December          1.76           12     202212
# 752  2023  December          2.80           12     202312
# 753  2024  December          2.71           12     202412
# 754  2025  December           NaN           12     202512
#
# [744 rows x 5 columns]

# %% [markdown]
# ### ACS Population Data

# %%
## TODO

# %% [markdown]
# ## Merge Data

# %% [markdown]
# ### Add weather data to bus data

# %%
stopuse_df['datekey'] = stopuse_df['datekey'].astype(str)
stopuse_df = stopuse_df.merge(precip_df[['year_month', 'total_precip']], how = 'left', left_on = 'datekey', right_on = 'year_month')
stopuse_df = stopuse_df.merge(temp_df[['year_month', 'avg_temp']], how = 'left', left_on = 'datekey', right_on = 'year_month')
stopuse_df.drop(columns = ['year_month_x', 'year_month_y'], inplace = True)
stopuse_df.head()
# Out:
#    clever_id stop_id            stop_name direction routes_ser  latitude  \
# 0       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 1       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 2       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 3       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
# 4       7858  E02110  5TH ST AT CAVIT AVE   Inbound    69, P69   40.3858
#
#    longitude mode     shelter stop_type  ...   time_period route_name  \
# 0     -79.76  Bus  No Shelter  Bus Stop  ...  Pre-pandemic         69
# 1     -79.76  Bus  No Shelter  Bus Stop  ...  Pre-pandemic         69
# 2     -79.76  Bus  No Shelter  Bus Stop  ...  Pre-pandemic         69
# 3     -79.76  Bus  No Shelter  Bus Stop  ...  Pre-pandemic        P69
# 4     -79.76  Bus  No Shelter  Bus Stop  ...  Pre-pandemic         69
#
#   serviceday total_ons  total_offs  days   avg_ons  avg_offs  total_precip  \
# 0        Sat      12.0         0.0     4  3.000000      0.00          5.34
# 1        Sun      14.0         0.0     6  2.333333      0.00          5.34
# 2    Weekday      64.0         1.0    20  3.200000      0.05          5.34
# 3    Weekday      39.0         0.0    20  1.950000      0.00          5.34
# 4        Sat      11.0         0.0     4  2.750000      0.00          3.69
#
#    avg_temp
# 0      69.0
# 1      69.0
# 2      69.0
# 3      69.0
# 4      35.2
#
# [5 rows x 21 columns]

# %%
ridership_df['year_month'] = ridership_df['year_month'].astype(str)
ridership_df = ridership_df.merge(precip_df[['year_month', 'total_precip']], how = 'left', on = 'year_month')
ridership_df = ridership_df.merge(temp_df[['year_month', 'avg_temp']], how = 'left', on = 'year_month')
ridership_df.head()
# Out:
#    _id route ridership_route_code    route_full_name current_garage mode  \
# 0    1     1                  001  1 - FREEPORT ROAD           Ross  Bus
# 1    2     4                  004      4 - TROY HILL           Ross  Bus
# 2    3     6                  006    6 - SPRING HILL           Ross  Bus
# 3    4     8                  008    8 - PERRYSVILLE           Ross  Bus
# 4    5    11                  011      11 - FINEVIEW           Ross  Bus
#
#   month_start year_month day_type  avg_riders  day_count  total_precip  \
# 0  2017-01-01     201701     SAT.      969.50          4          3.54
# 1  2017-01-01     201701     SAT.      218.25          4          3.54
# 2  2017-01-01     201701     SAT.      495.50          4          3.54
# 3  2017-01-01     201701     SAT.     1480.00          4          3.54
# 4  2017-01-01     201701     SAT.      208.00          4          3.54
#
#    avg_temp
# 0      34.6
# 1      34.6
# 2      34.6
# 3      34.6
# 4      34.6

# %% [markdown]
# ### Add ZIP code to bus data

# %%
import geopandas as gpd

lat_lon = stopuse_df[['stop_id', 'routes_ser', 'longitude', 'latitude']].drop_duplicates().copy()
gs = gpd.points_from_xy(lat_lon['longitude'], lat_lon['latitude'])
gs
# Out:
# <GeometryArray>
# [<POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>,
#  <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.7 40.4)>,
#  <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>,
#  <POINT (-79.8 40.4)>,
#  ...
#  <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>,
#  <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>,
#  <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>, <POINT (-79.8 40.4)>,
#  <POINT (-79.8 40.4)>]
# Length: 6774, dtype: geometry

# %%
## Store long-lat data in geopandas dataframe
points = gpd.GeoDataFrame(lat_lon, geometry=gs, crs='epsg:4326')
points
# Out:
#        stop_id routes_ser  longitude  latitude                    geometry
# 0       E02110    69, P69   -79.7600   40.3858  POINT (-79.76000 40.38580)
# 16      E02430    69, P69   -79.7525   40.3864  POINT (-79.75250 40.38640)
# 32      E20030    69, P69   -79.7576   40.3868  POINT (-79.75760 40.38680)
# 48      E20050    69, P69   -79.7591   40.3857  POINT (-79.75910 40.38570)
# 64      E70818    69, P69   -79.7503   40.3889  POINT (-79.75030 40.38890)
# ...        ...        ...        ...       ...                         ...
# 107551  E53290         69   -79.8077   40.3932  POINT (-79.80770 40.39320)
# 107563  E53300         69   -79.8093   40.3933  POINT (-79.80930 40.39330)
# 107575  E56995         69   -79.8098   40.3927  POINT (-79.80980 40.39270)
# 107587  E70960         69   -79.8098   40.3918  POINT (-79.80980 40.39180)
# 107599  E70980         69   -79.8086   40.3925  POINT (-79.80860 40.39250)
#
# [6774 rows x 5 columns]

# %%
## Import Allegheny County ZIP polygons
zipcodes = gpd.read_file("Data/Allegheny_County_Zip_Code_Boundaries.shp")
zipcodes = zipcodes.to_crs(4326)
zipcodes.head()
# Out:
#   GDB_GEOMAT  OBJECTID    ZIP            NAME     ZIPTYPE STATE  \
# 0       None         4  15007      BAKERSTOWN  NON-UNIQUE    PA
# 1       None         5  15014    BRACKENRIDGE  NON-UNIQUE    PA
# 2       None         6  15015  BRADFORD WOODS  NON-UNIQUE    PA
# 3       None         8  15018     BUENA VISTA  NON-UNIQUE    PA
# 4       None        14  15034      DRAVOSBURG  NON-UNIQUE    PA
#
#                                             geometry
# 0  POLYGON ((-79.92421 40.65180, -79.92421 40.651...
# 1  POLYGON ((-79.73576 40.61128, -79.73574 40.611...
# 2  POLYGON ((-80.07258 40.64491, -80.07240 40.644...
# 3  POLYGON ((-79.78014 40.29273, -79.77960 40.292...
# 4  POLYGON ((-79.88627 40.35929, -79.88607 40.359...

# %%
## Join the long-lat points and ZIP polygons
zip_points = points.sjoin(zipcodes, how='left')
zip_points[zip_points['ZIP'].isna()]
# Out:
#     stop_id routes_ser  longitude  latitude                    geometry  \
# 0    E02110    69, P69   -79.7600   40.3858  POINT (-79.76000 40.38580)
# 16   E02430    69, P69   -79.7525   40.3864  POINT (-79.75250 40.38640)
# 32   E20030    69, P69   -79.7576   40.3868  POINT (-79.75760 40.38680)
# 48   E20050    69, P69   -79.7591   40.3857  POINT (-79.75910 40.38570)
# 64   E70818    69, P69   -79.7503   40.3889  POINT (-79.75030 40.38890)
# 80   E70819    69, P69   -79.7484   40.3883  POINT (-79.74840 40.38830)
# 96   E70820    69, P69   -79.7523   40.3865  POINT (-79.75230 40.38650)
# 112  E70821    69, P69   -79.7568   40.3875  POINT (-79.75680 40.38750)
# 128  E70822    69, P69   -79.7576   40.3870  POINT (-79.75760 40.38700)
# 144  E70823    69, P69   -79.7587   40.3859  POINT (-79.75870 40.38590)
# 160  E70824    69, P69   -79.7605   40.3860  POINT (-79.76050 40.38600)
# 176  E70825    69, P69   -79.7614   40.3852  POINT (-79.76140 40.38520)
# 192  E70826    69, P69   -79.7609   40.3854  POINT (-79.76090 40.38540)
# 208  E70827    69, P69   -79.7571   40.3873  POINT (-79.75710 40.38730)
# 224  E70828    69, P69   -79.7484   40.3881  POINT (-79.74840 40.38810)
# 240  E70829    69, P69   -79.7503   40.3890  POINT (-79.75030 40.38900)
# 256  N01830          1   -79.7657   40.5626  POINT (-79.76570 40.56260)
# 268  N01935          1   -79.7663   40.5649  POINT (-79.76630 40.56490)
# 280  N03995          1   -79.7667   40.5623  POINT (-79.76670 40.56230)
# 292  N05685         14   -80.2281   40.5924  POINT (-80.22810 40.59240)
# 340  N27620          1   -79.7679   40.5634  POINT (-79.76790 40.56340)
# 352  N33470         14   -80.2300   40.5916  POINT (-80.23000 40.59160)
# 364  N33490         14   -80.2303   40.5923  POINT (-80.23030 40.59230)
# 376  N33500         14   -80.2304   40.5927  POINT (-80.23040 40.59270)
# 388  N33540         14   -80.2223   40.5801  POINT (-80.22230 40.58010)
# 400  N33560         14   -80.2240   40.5820  POINT (-80.22400 40.58200)
# 412  N33570         14   -80.2238   40.5818  POINT (-80.22380 40.58180)
# 424  N33580         14   -80.2253   40.5838  POINT (-80.22530 40.58380)
# 436  N33590         14   -80.2254   40.5840  POINT (-80.22540 40.58400)
# 448  N33595         14   -80.2274   40.5866  POINT (-80.22740 40.58660)
# 460  N33610         14   -80.2294   40.5895  POINT (-80.22940 40.58950)
# 472  N33660         14   -80.2293   40.5895  POINT (-80.22930 40.58950)
# 484  N33675         14   -80.2216   40.5799  POINT (-80.22160 40.57990)
# 496  N33677         14   -80.2214   40.5799  POINT (-80.22140 40.57990)
# 520  N71341         14   -80.2272   40.5865  POINT (-80.22720 40.58650)
#
#      index_right GDB_GEOMAT  OBJECTID  ZIP NAME ZIPTYPE STATE
# 0            NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 16           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 32           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 48           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 64           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 80           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 96           NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 112          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 128          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 144          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 160          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 176          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 192          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 208          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 224          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 240          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 256          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 268          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 280          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 292          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 340          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 352          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 364          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 376          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 388          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 400          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 412          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 424          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 436          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 448          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 460          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 472          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 484          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 496          NaN        NaN       NaN  NaN  NaN     NaN   NaN
# 520          NaN        NaN       NaN  NaN  NaN     NaN   NaN

# %%
## Account for missing ZIP data for ZIP codes just outside Allegheny County
conditions = [((zip_points['ZIP'].isna()) & (zip_points['routes_ser'] == '69, P69')), 
              ((zip_points['ZIP'].isna()) & (zip_points['routes_ser'] == '1')),
              ((zip_points['ZIP'].isna()) & (zip_points['routes_ser'] == '14'))]

values = ['15085', '15068', '15003']

zip_points['ZIP'] = np.select(conditions, values, default = zip_points['ZIP'])

zip_points[zip_points['ZIP'].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [stop_id, routes_ser, longitude, latitude, geometry, index_right, GDB_GEOMAT, OBJECTID, ZIP, NAME, ZIPTYPE, STATE]
# Index: []

# %%
zip_points = zip_points[['stop_id', 'routes_ser', 'ZIP']].copy()

# %%
stopuse_df = stopuse_df.merge(zip_points, how = 'left', on = ['stop_id', 'routes_ser'])
stopuse_df
# Out:
#         clever_id stop_id                  stop_name direction routes_ser  \
# 0            7858  E02110        5TH ST AT CAVIT AVE   Inbound    69, P69
# 1            7858  E02110        5TH ST AT CAVIT AVE   Inbound    69, P69
# 2            7858  E02110        5TH ST AT CAVIT AVE   Inbound    69, P69
# 3            7858  E02110        5TH ST AT CAVIT AVE   Inbound    69, P69
# 4            7858  E02110        5TH ST AT CAVIT AVE   Inbound    69, P69
# ...           ...     ...                        ...       ...        ...
# 107606      22643  E70980  HERMAN AVE AT COMMERCE ST      Both         69
# 107607      22643  E70980  HERMAN AVE AT COMMERCE ST      Both         69
# 107608      22643  E70980  HERMAN AVE AT COMMERCE ST      Both         69
# 107609      22643  E70980  HERMAN AVE AT COMMERCE ST      Both         69
# 107610      22643  E70980  HERMAN AVE AT COMMERCE ST      Both         69
#
#         latitude  longitude mode     shelter stop_type  ... route_name  \
# 0        40.3858   -79.7600  Bus  No Shelter  Bus Stop  ...         69
# 1        40.3858   -79.7600  Bus  No Shelter  Bus Stop  ...         69
# 2        40.3858   -79.7600  Bus  No Shelter  Bus Stop  ...         69
# 3        40.3858   -79.7600  Bus  No Shelter  Bus Stop  ...        P69
# 4        40.3858   -79.7600  Bus  No Shelter  Bus Stop  ...         69
# ...          ...        ...  ...         ...       ...  ...        ...
# 107606   40.3925   -79.8086  Bus  No Shelter  Bus Stop  ...         69
# 107607   40.3925   -79.8086  Bus  No Shelter  Bus Stop  ...         69
# 107608   40.3925   -79.8086  Bus  No Shelter  Bus Stop  ...         69
# 107609   40.3925   -79.8086  Bus  No Shelter  Bus Stop  ...         69
# 107610   40.3925   -79.8086  Bus  No Shelter  Bus Stop  ...         69
#
#        serviceday total_ons total_offs  days   avg_ons  avg_offs  \
# 0             Sat      12.0        0.0     4  3.000000  0.000000
# 1             Sun      14.0        0.0     6  2.333333  0.000000
# 2         Weekday      64.0        1.0    20  3.200000  0.050000
# 3         Weekday      39.0        0.0    20  1.950000  0.000000
# 4             Sat      11.0        0.0     4  2.750000  0.000000
# ...           ...       ...        ...   ...       ...       ...
# 107606        Sun       1.0        1.0     5  0.200000  0.200000
# 107607    Weekday      88.0       38.0    21  4.190476  1.809524
# 107608        Sat       1.0        1.0     4  0.250000  0.250000
# 107609        Sun       0.0        1.0     4  0.000000  0.250000
# 107610    Weekday      77.0       35.0    22  3.500000  1.590909
#
#         total_precip  avg_temp    ZIP
# 0               5.34      69.0  15085
# 1               5.34      69.0  15085
# 2               5.34      69.0  15085
# 3               5.34      69.0  15085
# 4               3.69      35.2  15085
# ...              ...       ...    ...
# 107606          0.92      64.6  15148
# 107607          0.92      64.6  15148
# 107608          2.67      51.3  15148
# 107609          2.67      51.3  15148
# 107610          2.67      51.3  15148
#
# [107611 rows x 22 columns]

# %% [markdown]
# ## Output Data

# %%
stopuse_df.to_csv("Data/stop_usage.csv", index = False)
ridership_df.to_csv("Data/ridership.csv", index = False)

# %%
#demo_df.to_csv("Data/zip_demo.csv", index = False)
#commute_df.to_csv("Data/zip_commute.csv", index = False)
