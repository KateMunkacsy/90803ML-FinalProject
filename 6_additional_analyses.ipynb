# %% [markdown]
# ## Step 6: Additional analyses
#
# **Project**: Predicting Bus Ridership \
# **Team**: T20 - Eurus Li, Garrett Kent, Kate Munkacsy

# %% [markdown]
# ### A. Initial setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### B. Prepare demographic data

# %%
demo_df = pd.read_excel("Data/ACS 5 Year_Demographic Data_2019-2023.xlsx", sheet_name = "Data", header = [0, 1])
demo_df.columns = demo_df.columns.map('_'.join)
demo_df.rename({'Unnamed: 0_level_0_Label':'Label'}, inplace = True, axis = 1)
demo_df.head()
# Out:
#                                Label Allegheny County, Pennsylvania_Estimate  \
# 0                        SEX AND AGE                                     NaN
# 1                   Total population                               1,240,476
# 2                               Male                                 604,817
# 3                             Female                                 635,659
# 4  Sex ratio (males per 100 females)                                    95.1
#
#   Allegheny County, Pennsylvania_Margin of Error  \
# 0                                            NaN
# 1                                          *****
# 2                                            ±35
# 3                                            ±35
# 4                                           ±0.1
#
#   Allegheny County, Pennsylvania_Percent  \
# 0                                    NaN
# 1                              1,240,476
# 2                                  48.8%
# 3                                  51.2%
# 4                                    (X)
#
#   Allegheny County, Pennsylvania_Percent Margin of Error ZCTA5 15003_Estimate  \
# 0                                                NaN                      NaN
# 1                                                (X)                   11,394
# 2                                               ±0.1                    5,748
# 3                                               ±0.1                    5,646
# 4                                                (X)                    101.8
#
#   ZCTA5 15003_Margin of Error ZCTA5 15003_Percent  \
# 0                         NaN                 NaN
# 1                        ±333              11,394
# 2                        ±307               50.4%
# 3                        ±302               49.6%
# 4                        ±9.0                 (X)
#
#   ZCTA5 15003_Percent Margin of Error ZCTA5 15005_Estimate  ...  \
# 0                                 NaN                  NaN  ...
# 1                                 (X)                9,574  ...
# 2                                ±2.2                4,579  ...
# 3                                ±2.2                4,995  ...
# 4                                 (X)                 91.7  ...
#
#   ZCTA5 16046_Percent ZCTA5 16046_Percent Margin of Error  \
# 0                 NaN                                 NaN
# 1              19,577                                 (X)
# 2               49.9%                                ±1.7
# 3               50.1%                                ±1.7
# 4                 (X)                                 (X)
#
#   ZCTA5 16055_Estimate ZCTA5 16055_Margin of Error ZCTA5 16055_Percent  \
# 0                  NaN                         NaN                 NaN
# 1                8,856                        ±421               8,856
# 2                4,438                        ±328               50.1%
# 3                4,418                        ±297               49.9%
# 4                100.5                       ±10.5                 (X)
#
#   ZCTA5 16055_Percent Margin of Error ZCTA5 16059_Estimate  \
# 0                                 NaN                  NaN
# 1                                 (X)                9,770
# 2                                ±2.6                4,800
# 3                                ±2.6                4,970
# 4                                 (X)                 96.6
#
#    ZCTA5 16059_Margin of Error ZCTA5 16059_Percent  \
# 0                          NaN                 NaN
# 1                         ±512               9,770
# 2                         ±364               49.1%
# 3                         ±319               50.9%
# 4                         ±9.0                 (X)
#
#   ZCTA5 16059_Percent Margin of Error
# 0                                 NaN
# 1                                 (X)
# 2                                ±2.3
# 3                                ±2.3
# 4                                 (X)
#
# [5 rows x 481 columns]

# %%
demo_df['Topic'] = np.where(demo_df.iloc[:, 1:].isnull().all(axis=1), demo_df['Label'], np.nan)
demo_df.insert(0, 'Topic', demo_df.pop('Topic'))
demo_df['Topic'] = demo_df['Topic'].ffill()
demo_df.head()
# Out:
#          Topic                              Label  \
# 0  SEX AND AGE                        SEX AND AGE
# 1  SEX AND AGE                   Total population
# 2  SEX AND AGE                               Male
# 3  SEX AND AGE                             Female
# 4  SEX AND AGE  Sex ratio (males per 100 females)
#
#   Allegheny County, Pennsylvania_Estimate  \
# 0                                     NaN
# 1                               1,240,476
# 2                                 604,817
# 3                                 635,659
# 4                                    95.1
#
#   Allegheny County, Pennsylvania_Margin of Error  \
# 0                                            NaN
# 1                                          *****
# 2                                            ±35
# 3                                            ±35
# 4                                           ±0.1
#
#   Allegheny County, Pennsylvania_Percent  \
# 0                                    NaN
# 1                              1,240,476
# 2                                  48.8%
# 3                                  51.2%
# 4                                    (X)
#
#   Allegheny County, Pennsylvania_Percent Margin of Error ZCTA5 15003_Estimate  \
# 0                                                NaN                      NaN
# 1                                                (X)                   11,394
# 2                                               ±0.1                    5,748
# 3                                               ±0.1                    5,646
# 4                                                (X)                    101.8
#
#   ZCTA5 15003_Margin of Error ZCTA5 15003_Percent  \
# 0                         NaN                 NaN
# 1                        ±333              11,394
# 2                        ±307               50.4%
# 3                        ±302               49.6%
# 4                        ±9.0                 (X)
#
#   ZCTA5 15003_Percent Margin of Error  ... ZCTA5 16046_Percent  \
# 0                                 NaN  ...                 NaN
# 1                                 (X)  ...              19,577
# 2                                ±2.2  ...               49.9%
# 3                                ±2.2  ...               50.1%
# 4                                 (X)  ...                 (X)
#
#   ZCTA5 16046_Percent Margin of Error ZCTA5 16055_Estimate  \
# 0                                 NaN                  NaN
# 1                                 (X)                8,856
# 2                                ±1.7                4,438
# 3                                ±1.7                4,418
# 4                                 (X)                100.5
#
#   ZCTA5 16055_Margin of Error ZCTA5 16055_Percent  \
# 0                         NaN                 NaN
# 1                        ±421               8,856
# 2                        ±328               50.1%
# 3                        ±297               49.9%
# 4                       ±10.5                 (X)
#
#   ZCTA5 16055_Percent Margin of Error ZCTA5 16059_Estimate  \
# 0                                 NaN                  NaN
# 1                                 (X)                9,770
# 2                                ±2.6                4,800
# 3                                ±2.6                4,970
# 4                                 (X)                 96.6
#
#   ZCTA5 16059_Margin of Error  ZCTA5 16059_Percent  \
# 0                         NaN                  NaN
# 1                        ±512                9,770
# 2                        ±364                49.1%
# 3                        ±319                50.9%
# 4                        ±9.0                  (X)
#
#   ZCTA5 16059_Percent Margin of Error
# 0                                 NaN
# 1                                 (X)
# 2                                ±2.3
# 3                                ±2.3
# 4                                 (X)
#
# [5 rows x 482 columns]

# %%
## Handle duplicate rows
demo_df = demo_df[~demo_df.iloc[:, 2:].isnull().all(axis=1)].copy()
demo_df.head()
# Out:
#          Topic                              Label  \
# 1  SEX AND AGE                   Total population
# 2  SEX AND AGE                               Male
# 3  SEX AND AGE                             Female
# 4  SEX AND AGE  Sex ratio (males per 100 females)
# 5  SEX AND AGE                      Under 5 years
#
#   Allegheny County, Pennsylvania_Estimate  \
# 1                               1,240,476
# 2                                 604,817
# 3                                 635,659
# 4                                    95.1
# 5                                  63,079
#
#   Allegheny County, Pennsylvania_Margin of Error  \
# 1                                          *****
# 2                                            ±35
# 3                                            ±35
# 4                                           ±0.1
# 5                                            ±29
#
#   Allegheny County, Pennsylvania_Percent  \
# 1                              1,240,476
# 2                                  48.8%
# 3                                  51.2%
# 4                                    (X)
# 5                                   5.1%
#
#   Allegheny County, Pennsylvania_Percent Margin of Error ZCTA5 15003_Estimate  \
# 1                                                (X)                   11,394
# 2                                               ±0.1                    5,748
# 3                                               ±0.1                    5,646
# 4                                                (X)                    101.8
# 5                                               ±0.1                      484
#
#   ZCTA5 15003_Margin of Error ZCTA5 15003_Percent  \
# 1                        ±333              11,394
# 2                        ±307               50.4%
# 3                        ±302               49.6%
# 4                        ±9.0                 (X)
# 5                        ±151                4.2%
#
#   ZCTA5 15003_Percent Margin of Error  ... ZCTA5 16046_Percent  \
# 1                                 (X)  ...              19,577
# 2                                ±2.2  ...               49.9%
# 3                                ±2.2  ...               50.1%
# 4                                 (X)  ...                 (X)
# 5                                ±1.3  ...                6.3%
#
#   ZCTA5 16046_Percent Margin of Error ZCTA5 16055_Estimate  \
# 1                                 (X)                8,856
# 2                                ±1.7                4,438
# 3                                ±1.7                4,418
# 4                                 (X)                100.5
# 5                                ±1.2                  269
#
#   ZCTA5 16055_Margin of Error ZCTA5 16055_Percent  \
# 1                        ±421               8,856
# 2                        ±328               50.1%
# 3                        ±297               49.9%
# 4                       ±10.5                 (X)
# 5                        ±108                3.0%
#
#   ZCTA5 16055_Percent Margin of Error ZCTA5 16059_Estimate  \
# 1                                 (X)                9,770
# 2                                ±2.6                4,800
# 3                                ±2.6                4,970
# 4                                 (X)                 96.6
# 5                                ±1.2                  640
#
#   ZCTA5 16059_Margin of Error  ZCTA5 16059_Percent  \
# 1                        ±512                9,770
# 2                        ±364                49.1%
# 3                        ±319                50.9%
# 4                        ±9.0                  (X)
# 5                        ±197                 6.6%
#
#   ZCTA5 16059_Percent Margin of Error
# 1                                 (X)
# 2                                ±2.3
# 3                                ±2.3
# 4                                 (X)
# 5                                ±1.9
#
# [5 rows x 482 columns]

# %%
## Keep the first topic-label instance
## This is the highest level of information, which suits our needs
demo_df.drop_duplicates(inplace = True)
demo_df = demo_df.groupby(["Topic", "Label"]).first()
demo_df = demo_df.reset_index()
demo_df.head()
# Out:
#                             Topic                                    Label  \
# 0  CITIZEN, VOTING AGE POPULATION          Citizen, 18 and over population
# 1  CITIZEN, VOTING AGE POPULATION                                   Female
# 2  CITIZEN, VOTING AGE POPULATION                                     Male
# 3     HISPANIC OR LATINO AND RACE  American Indian and Alaska Native alone
# 4     HISPANIC OR LATINO AND RACE                              Asian alone
#
#   Allegheny County, Pennsylvania_Estimate  \
# 0                                 972,967
# 1                                 506,455
# 2                                 466,512
# 3                                     692
# 4                                  51,073
#
#   Allegheny County, Pennsylvania_Margin of Error  \
# 0                                         ±1,561
# 1                                           ±920
# 2                                         ±1,043
# 3                                           ±126
# 4                                           ±948
#
#   Allegheny County, Pennsylvania_Percent  \
# 0                                972,967
# 1                                  52.1%
# 2                                  47.9%
# 3                                   0.1%
# 4                                   4.1%
#
#   Allegheny County, Pennsylvania_Percent Margin of Error ZCTA5 15003_Estimate  \
# 0                                                (X)                    9,180
# 1                                               ±0.1                    4,667
# 2                                               ±0.1                    4,513
# 3                                               ±0.1                        0
# 4                                               ±0.1                        7
#
#   ZCTA5 15003_Margin of Error ZCTA5 15003_Percent  \
# 0                        ±390               9,180
# 1                        ±309               50.8%
# 2                        ±288               49.2%
# 3                         ±18                0.0%
# 4                         ±12                0.1%
#
#   ZCTA5 15003_Percent Margin of Error  ... ZCTA5 16046_Percent  \
# 0                                 (X)  ...              13,696
# 1                                ±2.5  ...               49.9%
# 2                                ±2.5  ...               50.1%
# 3                                ±0.3  ...                0.0%
# 4                                ±0.1  ...                5.3%
#
#   ZCTA5 16046_Percent Margin of Error ZCTA5 16055_Estimate  \
# 0                                 (X)                6,994
# 1                                ±1.7                3,579
# 2                                ±1.7                3,415
# 3                                ±0.2                    0
# 4                                ±1.8                   92
#
#   ZCTA5 16055_Margin of Error ZCTA5 16055_Percent  \
# 0                        ±379               6,994
# 1                        ±260               51.2%
# 2                        ±269               48.8%
# 3                         ±16                0.0%
# 4                         ±89                1.0%
#
#   ZCTA5 16055_Percent Margin of Error ZCTA5 16059_Estimate  \
# 0                                 (X)                7,541
# 1                                ±2.6                3,820
# 2                                ±2.6                3,721
# 3                                ±0.3                    0
# 4                                ±1.0                    8
#
#   ZCTA5 16059_Margin of Error  ZCTA5 16059_Percent  \
# 0                        ±424                7,541
# 1                        ±231                50.7%
# 2                        ±288                49.3%
# 3                         ±16                 0.0%
# 4                         ±11                 0.1%
#
#   ZCTA5 16059_Percent Margin of Error
# 0                                 (X)
# 1                                ±2.0
# 2                                ±2.0
# 3                                ±0.3
# 4                                ±0.1
#
# [5 rows x 482 columns]

# %%
demo_melt_df = demo_df.melt(id_vars = ['Topic', 'Label'], var_name = 'Location')
demo_melt_df[['Location', 'Estimate Type']] = demo_melt_df['Location'].str.split('_', expand=True)
demo_melt_df.head()
# Out:
#                             Topic                                    Label  \
# 0  CITIZEN, VOTING AGE POPULATION          Citizen, 18 and over population
# 1  CITIZEN, VOTING AGE POPULATION                                   Female
# 2  CITIZEN, VOTING AGE POPULATION                                     Male
# 3     HISPANIC OR LATINO AND RACE  American Indian and Alaska Native alone
# 4     HISPANIC OR LATINO AND RACE                              Asian alone
#
#                          Location    value Estimate Type
# 0  Allegheny County, Pennsylvania  972,967      Estimate
# 1  Allegheny County, Pennsylvania  506,455      Estimate
# 2  Allegheny County, Pennsylvania  466,512      Estimate
# 3  Allegheny County, Pennsylvania      692      Estimate
# 4  Allegheny County, Pennsylvania   51,073      Estimate

# %%
final_demo = demo_melt_df.pivot(index=['Topic', 'Label', 'Location'], columns = "Estimate Type", values = "value").reset_index()
final_demo.head()
# Out:
# Estimate Type                           Topic  \
# 0              CITIZEN, VOTING AGE POPULATION
# 1              CITIZEN, VOTING AGE POPULATION
# 2              CITIZEN, VOTING AGE POPULATION
# 3              CITIZEN, VOTING AGE POPULATION
# 4              CITIZEN, VOTING AGE POPULATION
#
# Estimate Type                            Label  \
# 0              Citizen, 18 and over population
# 1              Citizen, 18 and over population
# 2              Citizen, 18 and over population
# 3              Citizen, 18 and over population
# 4              Citizen, 18 and over population
#
# Estimate Type                        Location Estimate Margin of Error  \
# 0              Allegheny County, Pennsylvania  972,967          ±1,561
# 1                                 ZCTA5 15003    9,180            ±390
# 2                                 ZCTA5 15005    8,089            ±448
# 3                                 ZCTA5 15006       69            ±102
# 4                                 ZCTA5 15007    401.0            ±386
#
# Estimate Type  Percent Percent Margin of Error
# 0              972,967                     (X)
# 1                9,180                     (X)
# 2                8,089                     (X)
# 3                   69                     (X)
# 4                  401                     (X)

# %%
final_demo['ZIP'] = np.where(final_demo['Location'].str.startswith('ZCTA5'), final_demo['Location'].str[-5:], '')
final_demo[final_demo['ZIP'] == ''].count()
# Out:
# Estimate Type
# Topic                      84
# Label                      84
# Location                   84
# Estimate                   84
# Margin of Error            84
# Percent                    84
# Percent Margin of Error    84
# ZIP                        84
# dtype: int64

# %%
final_demo = final_demo[['Location', 'ZIP', 'Topic', 'Label', 'Estimate', 'Margin of Error', 'Percent', 'Percent Margin of Error']].copy()
final_demo.head()
# Out:
# Estimate Type                        Location    ZIP  \
# 0              Allegheny County, Pennsylvania
# 1                                 ZCTA5 15003  15003
# 2                                 ZCTA5 15005  15005
# 3                                 ZCTA5 15006  15006
# 4                                 ZCTA5 15007  15007
#
# Estimate Type                           Topic  \
# 0              CITIZEN, VOTING AGE POPULATION
# 1              CITIZEN, VOTING AGE POPULATION
# 2              CITIZEN, VOTING AGE POPULATION
# 3              CITIZEN, VOTING AGE POPULATION
# 4              CITIZEN, VOTING AGE POPULATION
#
# Estimate Type                            Label Estimate Margin of Error  \
# 0              Citizen, 18 and over population  972,967          ±1,561
# 1              Citizen, 18 and over population    9,180            ±390
# 2              Citizen, 18 and over population    8,089            ±448
# 3              Citizen, 18 and over population       69            ±102
# 4              Citizen, 18 and over population    401.0            ±386
#
# Estimate Type  Percent Percent Margin of Error
# 0              972,967                     (X)
# 1                9,180                     (X)
# 2                8,089                     (X)
# 3                   69                     (X)
# 4                  401                     (X)

# %% [markdown]
# ### C. Prepare commute data

# %%
commute_df = pd.read_excel("Data/ACS 5 Year_Commuting Data_2019-2023.xlsx", sheet_name = "Data",  header = [0, 1, 2])
commute_df.columns = commute_df.columns.map('_'.join)
commute_df.rename({'Unnamed: 0_level_0_Unnamed: 0_level_1_Label':'Label'}, inplace = True, axis = 1)
commute_df.head()
# Out:
#                              Label  \
# 0        Workers 16 years and over
# 1  MEANS OF TRANSPORTATION TO WORK
# 2               Car, truck, or van
# 3                      Drove alone
# 4                        Carpooled
#
#   Allegheny County, Pennsylvania_Total_Estimate  \
# 0                                       625,443
# 1                                           NaN
# 2                                         69.9%
# 3                                         63.3%
# 4                                          6.6%
#
#   Allegheny County, Pennsylvania_Total_Margin of Error  \
# 0                                             ±3,226
# 1                                                NaN
# 2                                               ±0.5
# 3                                               ±0.4
# 4                                               ±0.2
#
#   Allegheny County, Pennsylvania_Male_Estimate  \
# 0                                      324,264
# 1                                          NaN
# 2                                        71.9%
# 3                                        65.7%
# 4                                         6.2%
#
#   Allegheny County, Pennsylvania_Male_Margin of Error  \
# 0                                             ±2,203
# 1                                                NaN
# 2                                               ±0.7
# 3                                               ±0.6
# 4                                               ±0.4
#
#   Allegheny County, Pennsylvania_Female_Estimate  \
# 0                                        301,179
# 1                                            NaN
# 2                                          67.7%
# 3                                          60.7%
# 4                                           7.1%
#
#   Allegheny County, Pennsylvania_Female_Margin of Error  \
# 0                                             ±2,392
# 1                                                NaN
# 2                                               ±0.7
# 3                                               ±0.7
# 4                                               ±0.3
#
#   ZCTA5 15003_Total_Estimate ZCTA5 15003_Total_Margin of Error  \
# 0                      5,653                              ±482
# 1                        NaN                               NaN
# 2                      84.6%                              ±3.2
# 3                      75.0%                              ±5.0
# 4                       9.6%                              ±3.8
#
#   ZCTA5 15003_Male_Estimate  ... ZCTA5 16055_Male_Estimate  \
# 0                     2,803  ...                     2,057
# 1                       NaN  ...                       NaN
# 2                     81.1%  ...                     86.8%
# 3                     73.9%  ...                     79.5%
# 4                      7.2%  ...                      7.3%
#
#   ZCTA5 16055_Male_Margin of Error ZCTA5 16055_Female_Estimate  \
# 0                             ±237                       1,901
# 1                              NaN                         NaN
# 2                             ±6.3                       84.8%
# 3                             ±7.0                       79.9%
# 4                             ±3.6                        4.9%
#
#   ZCTA5 16055_Female_Margin of Error ZCTA5 16059_Total_Estimate  \
# 0                               ±256                      4,538
# 1                                NaN                        NaN
# 2                               ±5.5                      81.2%
# 3                               ±6.2                      76.3%
# 4                               ±2.9                       4.9%
#
#   ZCTA5 16059_Total_Margin of Error ZCTA5 16059_Male_Estimate  \
# 0                              ±398                     2,423
# 1                               NaN                       NaN
# 2                              ±6.4                     82.7%
# 3                              ±6.7                     79.2%
# 4                              ±2.3                      3.5%
#
#   ZCTA5 16059_Male_Margin of Error ZCTA5 16059_Female_Estimate  \
# 0                             ±254                       2,115
# 1                              NaN                         NaN
# 2                             ±6.5                       79.5%
# 3                             ±6.9                       73.0%
# 4                             ±2.7                        6.5%
#
#   ZCTA5 16059_Female_Margin of Error
# 0                               ±267
# 1                                NaN
# 2                               ±7.8
# 3                               ±8.6
# 4                               ±3.7
#
# [5 rows x 721 columns]

# %%
commute_df['Topic'] = np.where(commute_df.iloc[:, 1:].isnull().all(axis=1), commute_df['Label'], np.nan)
commute_df.insert(0, 'Topic', commute_df.pop('Topic'))
commute_df['Topic'] = commute_df['Topic'].ffill()
commute_df.head()
# Out:
#                              Topic                            Label  \
# 0                              NaN        Workers 16 years and over
# 1  MEANS OF TRANSPORTATION TO WORK  MEANS OF TRANSPORTATION TO WORK
# 2  MEANS OF TRANSPORTATION TO WORK               Car, truck, or van
# 3  MEANS OF TRANSPORTATION TO WORK                      Drove alone
# 4  MEANS OF TRANSPORTATION TO WORK                        Carpooled
#
#   Allegheny County, Pennsylvania_Total_Estimate  \
# 0                                       625,443
# 1                                           NaN
# 2                                         69.9%
# 3                                         63.3%
# 4                                          6.6%
#
#   Allegheny County, Pennsylvania_Total_Margin of Error  \
# 0                                             ±3,226
# 1                                                NaN
# 2                                               ±0.5
# 3                                               ±0.4
# 4                                               ±0.2
#
#   Allegheny County, Pennsylvania_Male_Estimate  \
# 0                                      324,264
# 1                                          NaN
# 2                                        71.9%
# 3                                        65.7%
# 4                                         6.2%
#
#   Allegheny County, Pennsylvania_Male_Margin of Error  \
# 0                                             ±2,203
# 1                                                NaN
# 2                                               ±0.7
# 3                                               ±0.6
# 4                                               ±0.4
#
#   Allegheny County, Pennsylvania_Female_Estimate  \
# 0                                        301,179
# 1                                            NaN
# 2                                          67.7%
# 3                                          60.7%
# 4                                           7.1%
#
#   Allegheny County, Pennsylvania_Female_Margin of Error  \
# 0                                             ±2,392
# 1                                                NaN
# 2                                               ±0.7
# 3                                               ±0.7
# 4                                               ±0.3
#
#   ZCTA5 15003_Total_Estimate ZCTA5 15003_Total_Margin of Error  ...  \
# 0                      5,653                              ±482  ...
# 1                        NaN                               NaN  ...
# 2                      84.6%                              ±3.2  ...
# 3                      75.0%                              ±5.0  ...
# 4                       9.6%                              ±3.8  ...
#
#   ZCTA5 16055_Male_Estimate ZCTA5 16055_Male_Margin of Error  \
# 0                     2,057                             ±237
# 1                       NaN                              NaN
# 2                     86.8%                             ±6.3
# 3                     79.5%                             ±7.0
# 4                      7.3%                             ±3.6
#
#   ZCTA5 16055_Female_Estimate ZCTA5 16055_Female_Margin of Error  \
# 0                       1,901                               ±256
# 1                         NaN                                NaN
# 2                       84.8%                               ±5.5
# 3                       79.9%                               ±6.2
# 4                        4.9%                               ±2.9
#
#   ZCTA5 16059_Total_Estimate ZCTA5 16059_Total_Margin of Error  \
# 0                      4,538                              ±398
# 1                        NaN                               NaN
# 2                      81.2%                              ±6.4
# 3                      76.3%                              ±6.7
# 4                       4.9%                              ±2.3
#
#   ZCTA5 16059_Male_Estimate ZCTA5 16059_Male_Margin of Error  \
# 0                     2,423                             ±254
# 1                       NaN                              NaN
# 2                     82.7%                             ±6.5
# 3                     79.2%                             ±6.9
# 4                      3.5%                             ±2.7
#
#   ZCTA5 16059_Female_Estimate ZCTA5 16059_Female_Margin of Error
# 0                       2,115                               ±267
# 1                         NaN                                NaN
# 2                       79.5%                               ±7.8
# 3                       73.0%                               ±8.6
# 4                        6.5%                               ±3.7
#
# [5 rows x 722 columns]

# %%
## Handle duplicate rows
commute_df = commute_df[~commute_df.iloc[:, 2:].isnull().all(axis=1)].copy()
commute_df.head()
# Out:
#                              Topic                      Label  \
# 0                              NaN  Workers 16 years and over
# 2  MEANS OF TRANSPORTATION TO WORK         Car, truck, or van
# 3  MEANS OF TRANSPORTATION TO WORK                Drove alone
# 4  MEANS OF TRANSPORTATION TO WORK                  Carpooled
# 5  MEANS OF TRANSPORTATION TO WORK        In 2-person carpool
#
#   Allegheny County, Pennsylvania_Total_Estimate  \
# 0                                       625,443
# 2                                         69.9%
# 3                                         63.3%
# 4                                          6.6%
# 5                                          5.5%
#
#   Allegheny County, Pennsylvania_Total_Margin of Error  \
# 0                                             ±3,226
# 2                                               ±0.5
# 3                                               ±0.4
# 4                                               ±0.2
# 5                                               ±0.2
#
#   Allegheny County, Pennsylvania_Male_Estimate  \
# 0                                      324,264
# 2                                        71.9%
# 3                                        65.7%
# 4                                         6.2%
# 5                                         5.1%
#
#   Allegheny County, Pennsylvania_Male_Margin of Error  \
# 0                                             ±2,203
# 2                                               ±0.7
# 3                                               ±0.6
# 4                                               ±0.4
# 5                                               ±0.3
#
#   Allegheny County, Pennsylvania_Female_Estimate  \
# 0                                        301,179
# 2                                          67.7%
# 3                                          60.7%
# 4                                           7.1%
# 5                                           5.9%
#
#   Allegheny County, Pennsylvania_Female_Margin of Error  \
# 0                                             ±2,392
# 2                                               ±0.7
# 3                                               ±0.7
# 4                                               ±0.3
# 5                                               ±0.3
#
#   ZCTA5 15003_Total_Estimate ZCTA5 15003_Total_Margin of Error  ...  \
# 0                      5,653                              ±482  ...
# 2                      84.6%                              ±3.2  ...
# 3                      75.0%                              ±5.0  ...
# 4                       9.6%                              ±3.8  ...
# 5                       9.4%                              ±3.8  ...
#
#   ZCTA5 16055_Male_Estimate ZCTA5 16055_Male_Margin of Error  \
# 0                     2,057                             ±237
# 2                     86.8%                             ±6.3
# 3                     79.5%                             ±7.0
# 4                      7.3%                             ±3.6
# 5                      7.3%                             ±3.6
#
#   ZCTA5 16055_Female_Estimate ZCTA5 16055_Female_Margin of Error  \
# 0                       1,901                               ±256
# 2                       84.8%                               ±5.5
# 3                       79.9%                               ±6.2
# 4                        4.9%                               ±2.9
# 5                        3.4%                               ±2.7
#
#   ZCTA5 16059_Total_Estimate ZCTA5 16059_Total_Margin of Error  \
# 0                      4,538                              ±398
# 2                      81.2%                              ±6.4
# 3                      76.3%                              ±6.7
# 4                       4.9%                              ±2.3
# 5                       4.7%                              ±2.3
#
#   ZCTA5 16059_Male_Estimate ZCTA5 16059_Male_Margin of Error  \
# 0                     2,423                             ±254
# 2                     82.7%                             ±6.5
# 3                     79.2%                             ±6.9
# 4                      3.5%                             ±2.7
# 5                      3.1%                             ±2.6
#
#   ZCTA5 16059_Female_Estimate ZCTA5 16059_Female_Margin of Error
# 0                       2,115                               ±267
# 2                       79.5%                               ±7.8
# 3                       73.0%                               ±8.6
# 4                        6.5%                               ±3.7
# 5                        6.5%                               ±3.7
#
# [5 rows x 722 columns]

# %%
## Keep the first topic-label instance
## This is the highest level of information, which suits our needs
commute_df.drop_duplicates(inplace = True)
commute_df = commute_df.groupby(["Topic", "Label"]).first()
commute_df = commute_df.reset_index()
commute_df.head()
# Out:
#                              Topic                Label  \
# 0  MEANS OF TRANSPORTATION TO WORK              Bicycle
# 1  MEANS OF TRANSPORTATION TO WORK   Car, truck, or van
# 2  MEANS OF TRANSPORTATION TO WORK            Carpooled
# 3  MEANS OF TRANSPORTATION TO WORK          Drove alone
# 4  MEANS OF TRANSPORTATION TO WORK  In 2-person carpool
#
#   Allegheny County, Pennsylvania_Total_Estimate  \
# 0                                          0.4%
# 1                                         69.9%
# 2                                          6.6%
# 3                                         63.3%
# 4                                          5.5%
#
#   Allegheny County, Pennsylvania_Total_Margin of Error  \
# 0                                               ±0.1
# 1                                               ±0.5
# 2                                               ±0.2
# 3                                               ±0.4
# 4                                               ±0.2
#
#   Allegheny County, Pennsylvania_Male_Estimate  \
# 0                                         0.6%
# 1                                        71.9%
# 2                                         6.2%
# 3                                        65.7%
# 4                                         5.1%
#
#   Allegheny County, Pennsylvania_Male_Margin of Error  \
# 0                                               ±0.1
# 1                                               ±0.7
# 2                                               ±0.4
# 3                                               ±0.6
# 4                                               ±0.3
#
#   Allegheny County, Pennsylvania_Female_Estimate  \
# 0                                           0.1%
# 1                                          67.7%
# 2                                           7.1%
# 3                                          60.7%
# 4                                           5.9%
#
#   Allegheny County, Pennsylvania_Female_Margin of Error  \
# 0                                               ±0.1
# 1                                               ±0.7
# 2                                               ±0.3
# 3                                               ±0.7
# 4                                               ±0.3
#
#   ZCTA5 15003_Total_Estimate ZCTA5 15003_Total_Margin of Error  ...  \
# 0                       0.0%                              ±0.5  ...
# 1                      84.6%                              ±3.2  ...
# 2                       9.6%                              ±3.8  ...
# 3                      75.0%                              ±5.0  ...
# 4                       9.4%                              ±3.8  ...
#
#   ZCTA5 16055_Male_Estimate ZCTA5 16055_Male_Margin of Error  \
# 0                      0.0%                             ±1.4
# 1                     86.8%                             ±6.3
# 2                      7.3%                             ±3.6
# 3                     79.5%                             ±7.0
# 4                      7.3%                             ±3.6
#
#   ZCTA5 16055_Female_Estimate ZCTA5 16055_Female_Margin of Error  \
# 0                        0.0%                               ±1.6
# 1                       84.8%                               ±5.5
# 2                        4.9%                               ±2.9
# 3                       79.9%                               ±6.2
# 4                        3.4%                               ±2.7
#
#   ZCTA5 16059_Total_Estimate ZCTA5 16059_Total_Margin of Error  \
# 0                       0.0%                              ±0.7
# 1                      81.2%                              ±6.4
# 2                       4.9%                              ±2.3
# 3                      76.3%                              ±6.7
# 4                       4.7%                              ±2.3
#
#   ZCTA5 16059_Male_Estimate ZCTA5 16059_Male_Margin of Error  \
# 0                      0.0%                             ±1.2
# 1                     82.7%                             ±6.5
# 2                      3.5%                             ±2.7
# 3                     79.2%                             ±6.9
# 4                      3.1%                             ±2.6
#
#   ZCTA5 16059_Female_Estimate ZCTA5 16059_Female_Margin of Error
# 0                        0.0%                               ±1.4
# 1                       79.5%                               ±7.8
# 2                        6.5%                               ±3.7
# 3                       73.0%                               ±8.6
# 4                        6.5%                               ±3.7
#
# [5 rows x 722 columns]

# %%
commute_melt_df = commute_df.melt(id_vars = ['Topic', 'Label'], var_name = 'Location')
commute_melt_df[['Location', 'Subgroup', 'Estimate Type']] = commute_melt_df['Location'].str.split('_', expand=True)
commute_melt_df.head()
# Out:
#                              Topic                Label  \
# 0  MEANS OF TRANSPORTATION TO WORK              Bicycle
# 1  MEANS OF TRANSPORTATION TO WORK   Car, truck, or van
# 2  MEANS OF TRANSPORTATION TO WORK            Carpooled
# 3  MEANS OF TRANSPORTATION TO WORK          Drove alone
# 4  MEANS OF TRANSPORTATION TO WORK  In 2-person carpool
#
#                          Location  value Subgroup Estimate Type
# 0  Allegheny County, Pennsylvania   0.4%    Total      Estimate
# 1  Allegheny County, Pennsylvania  69.9%    Total      Estimate
# 2  Allegheny County, Pennsylvania   6.6%    Total      Estimate
# 3  Allegheny County, Pennsylvania  63.3%    Total      Estimate
# 4  Allegheny County, Pennsylvania   5.5%    Total      Estimate

# %%
final_commute = commute_melt_df.pivot(index=['Topic', 'Label', 'Subgroup', 'Location'], columns = "Estimate Type", values = "value").reset_index()
final_commute.head()
# Out:
# Estimate Type                            Topic    Label Subgroup  \
# 0              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female
# 1              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female
# 2              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female
# 3              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female
# 4              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female
#
# Estimate Type                        Location Estimate Margin of Error
# 0              Allegheny County, Pennsylvania     0.1%            ±0.1
# 1                                 ZCTA5 15003     0.0%            ±1.0
# 2                                 ZCTA5 15005     0.0%            ±1.3
# 3                                 ZCTA5 15006    32.0%           ±12.8
# 4                                 ZCTA5 15007     0.0%           ±26.1

# %%
final_commute['ZIP'] = np.where(final_commute['Location'].str.startswith('ZCTA5'), final_commute['Location'].str[-5:], '')
final_commute[final_commute['ZIP'] == ''].count()
# Out:
# Estimate Type
# Topic              168
# Label              168
# Subgroup           168
# Location           168
# Estimate           168
# Margin of Error    168
# ZIP                168
# dtype: int64

# %%
final_commute = final_commute[['Location', 'ZIP', 'Topic', 'Label', 'Subgroup', 'Estimate', 'Margin of Error']].copy()
final_commute.head()
# Out:
# Estimate Type                        Location    ZIP  \
# 0              Allegheny County, Pennsylvania
# 1                                 ZCTA5 15003  15003
# 2                                 ZCTA5 15005  15005
# 3                                 ZCTA5 15006  15006
# 4                                 ZCTA5 15007  15007
#
# Estimate Type                            Topic    Label Subgroup Estimate  \
# 0              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female     0.1%
# 1              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female     0.0%
# 2              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female     0.0%
# 3              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female    32.0%
# 4              MEANS OF TRANSPORTATION TO WORK  Bicycle   Female     0.0%
#
# Estimate Type Margin of Error
# 0                        ±0.1
# 1                        ±1.0
# 2                        ±1.3
# 3                       ±12.8
# 4                       ±26.1

# %% [markdown]
# ### D. Join Census data with bus data

# %%
## TODO
